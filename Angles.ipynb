# %% [markdown]
# # **ANGLES OF ELEVATION AND DEPRESSION**

# %% [markdown]
# Consider a plane in level flight flying over an observer on the ground. The pilot must keep this observer in sight. The angle made with the horizontal from the pilot to the ground observer is called the Angle of Depression ($∠D$). The angle made with the ground from the observer up to the pilot is called the Angle of Elevation ($\angle E$). How should the measure of these angles be related to each other?

# %% [markdown]
# Use the following link to take a look at the relationship between angle of depression from the point of view of the Cessna, and angle of elevation from the point of view of the ground observer. You can click the animation button as well or use the slider to change position of the airplane. What do you notice?
# [LINK](https://www.geogebra.org/m/w8krhngh)

# %% [markdown]
# ![Screenshot 2022-04-06 8.18.56 AM.png](data:image/png;base64,...)![Screenshot 2022-04-06 8.20.06 AM.png](data:image/png;base64,...)![Screenshot 2022-04-06 8.20.29 AM.png](data:image/png;base64,...)

# %% [markdown]
# If you observed that it is always true that $∠D \cong ∠E$ you are definitely correct! But what do you think the reason for this might be? *Hint*: Look back
# at **Unit 3** on parallel lines and their angles with a transversal.

# %% [markdown]
# The horizontal flight of the plane is parallel to the ground (ideally also perfectly horizontal). The sighting line from the plane to the downrange observer is a transversal. Thus by Theorem 3.2XXX $∠D\cong∠E$ because they are alternate interior angles.

# %% [markdown]
# Now click the "Show Right Triangle" button. This will show the altitude and downrange distance, as well as show a different angle (in red). You should see something like this:
# ![Angles 4.png](data:image/png;base64,...)

# %% [markdown]
# Take a look at the angle in red. Let's call it $\color{red}{\angle C}$. What is the relationship between $\color{red}{\angle C}$ and $\color{green}{\angle E}$? Verify your guess by once again either clicking the animation button or moving the slider. Do you notice that $m{\angle C}$ + $m{\angle E}=90^\text{o}$? If so you're absolutely right! The measure of these angles must always be $90^\text{o}$, therefore we call them *complimentary*. ![Screenshot 2022-04-06 10.21.33 AM.png](data:image/png;base64,...)

# %% [markdown]
# There are two ways to show why that must always be true. Taking a look at them will help us review our knowledge of angle facts of both parallel lines as well as triangles.

# %% [markdown]
# Recall that the measures of all the interior angles of a triangle must sum to $180^\text{o}$. Since horizontal is always perpindicular vertical by definition, our triangle will always be a right triangle with the right angle located where the altitude line intersects the ground (ideally horozontal). Therefore the two acute angles of a right triangle must always be complimentary

# %% [markdown]
# We can also observe that angles $\angle{D}\text{ and }\angle{C}$ are complimentary as well. We know this must be true from our previous observation that $\angle{E}\cong\angle{D}$, so then by the Transitive Property if $\angle{E}\text{ and }\angle{D}$ are congruent, and $\angle{E}\text{ and }\angle{C}$ are complimentary then angles $\angle{D}\text{ and }\angle{C}$ must be complimentary as well.

# %% [markdown]
# *Extra Credit Challenge*: Use these two conclusions to demonstrate the Exterior Angles Theorem in the case of Right Triangles!

# %% [markdown]
# In the next unit we will use this same demonstration to introduce the sine, cosine, and tagent ratios of a right triangle. Until then,

# %% [markdown]
# ✈$\begin{align}\text{HAPPY FLYING!!!}\\\\\end{align}$ ✈
